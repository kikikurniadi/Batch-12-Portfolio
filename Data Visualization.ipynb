# %% [markdown]
# # Assignment

# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('train.csv')

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %% [markdown]
# # 1. Count of one categorical feature

# %%
SaleCondition_count = df.groupby(['Neighborhood'],as_index=False).size()

# %%
sns.barplot(x=SaleCondition_count['Neighborhood'],
            y=SaleCondition_count['size'])

# %%
# Construct a Dataset
SaleCondition_count = df.groupby(['Neighborhood'],as_index=False).size()
SaleCondition_count = SaleCondition_count.sort_values(['size'],ascending=False)

# %%
sns.barplot(x=SaleCondition_count['Neighborhood'],
            y=SaleCondition_count['size'])
plt.show()

# %%
sns.barplot(x=SaleCondition_count['size'],
            y=SaleCondition_count['Neighborhood'])
plt.show()

# %% [markdown]
# # 2. Distribution of one continuous feature

# %%
sns.displot(x=df['SalePrice'])

# %%
sns.displot(x=df['SalePrice'],kind='kde')

# %%
sns.displot(x=df['SalePrice'],kde=True)

# %% [markdown]
# # 3. Categorical-continuous

# %%
sns.boxplot(x=df['SaleCondition'],
            y=df['YrSold'])

# %%
# Construct data
def is_auto(Sale):
    if 'Normal' in Sale:
        return 'Normal'
    else:
        return 'Non Normal'

# %%
df['Sale'] = df['SaleCondition'].apply(is_auto)
df['Sale'].value_counts()
# Out:
# Normal        1198
# Non Normal     262
# Name: Sale, dtype: int64

# %%
sns.boxplot(x=df['Sale'],
            y=df['YrSold']
           )

# %% [markdown]
# # 4. Continuous-continuous

# %%
sns.scatterplot(x=df['SalePrice'],y=df['SaleCondition'])

# %%
sns.scatterplot(x = df['SalePrice'],
                y = df['YrSold'],
                hue=df['SaleCondition'])
